# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import matplotlib.pyplot as plt 
from transfer_models import *
# Out:
# Using TensorFlow backend.

# %%
m0 = do_experiment("resnet",[], augment=True, load=False, epo1=4, epo2=4)
# Out:
# initializer = he_normal
# loading /mnt/data/train_aug.npz
# loading val.npz
# loading test.npz
# Train on 51840 samples, validate on 2160 samples
# Epoch 1/4
# 504s - loss: 1.4806 - acc: 0.5190 - val_loss: 1.3887 - val_acc: 0.5546
# Epoch 2/4
# 493s - loss: 0.9396 - acc: 0.6935 - val_loss: 0.8774 - val_acc: 0.7065
# Epoch 3/4
# 493s - loss: 0.8248 - acc: 0.7264 - val_loss: 0.8129 - val_acc: 0.7259
# Epoch 4/4
# 493s - loss: 0.7596 - acc: 0.7466 - val_loss: 0.7757 - val_acc: 0.7398
# set learning rate and recompile model
# Train on 51840 samples, validate on 2160 samples
# Epoch 1/4
# 593s - loss: 0.6114 - acc: 0.7937 - val_loss: 0.6586 - val_acc: 0.7736
# Epoch 2/4
# 590s - loss: 0.3835 - acc: 0.8800 - val_loss: 0.6355 - val_acc: 0.7829
# Epoch 3/4
# 591s - loss: 0.2382 - acc: 0.9338 - val_loss: 0.6513 - val_acc: 0.7912
# Epoch 4/4
# 591s - loss: 0.1394 - acc: 0.9690 - val_loss: 0.6824 - val_acc: 0.7907
# 3600/3600 [==============================] - 37s
# top 1 accuracy = 0.784444
# ...

# %%
m1 = do_experiment("resnet",[128], lr=5e-3, augment=True, load=False, epo1=10, epo2=20)
# Out:
# initializer = he_normal
# added fc-128, dropout keep prob 0.500000, l2 reg 0.005000
# loading /mnt/data/train_aug.npz
# loading val.npz
# loading test.npz
# Train on 51840 samples, validate on 2160 samples
# Epoch 1/10
# 496s - loss: 1.8009 - acc: 0.5142 - val_loss: 1.7086 - val_acc: 0.5352
# Epoch 2/10
# 495s - loss: 1.7030 - acc: 0.5089 - val_loss: 1.2571 - val_acc: 0.6843
# Epoch 3/10
# 495s - loss: 1.6984 - acc: 0.5065 - val_loss: 1.3158 - val_acc: 0.6634
# Epoch 4/10
# 495s - loss: 1.6717 - acc: 0.5063 - val_loss: 1.3490 - val_acc: 0.6671
# Epoch 5/10
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-82912fadb5c0> in <module>()
# ----> 1 m1 = do_experiment("resnet",[128], lr=5e-3, augment=True, load=False, epo1=10, epo2=20)
#
# ~/vgg_transfer/transfer_models.py in do_experiment(base_name, hidden_list, augment, load, lr, epo1, epo2, reg_list, prep)
# ...

# %%
m1 = do_experiment("resnet",[128], lr=1e-4, augment=False, load_model=False, epo1=20, epo2=20, verbose=1)
# Out:
# initializer = he_normal
# added fc-128, dropout keep prob 0.500000, l2 reg 0.005000
# loading train.npz
# loading val.npz
# loading test.npz
# Train on 8640 samples, validate on 2160 samples
# Epoch 1/20
# 8640/8640 [==============================] - 98s - loss: 2.8871 - acc: 0.3781 - val_loss: 1.9277 - val_acc: 0.7431
# Epoch 2/20
# 8640/8640 [==============================] - 95s - loss: 1.9783 - acc: 0.6755 - val_loss: 1.6091 - val_acc: 0.8009
# Epoch 3/20
# 8640/8640 [==============================] - 95s - loss: 1.7295 - acc: 0.7442 - val_loss: 1.5065 - val_acc: 0.8162
# Epoch 4/20
# 8640/8640 [==============================] - 95s - loss: 1.5975 - acc: 0.7750 - val_loss: 1.4365 - val_acc: 0.8241
# Epoch 5/20
# 8640/8640 [==============================] - 95s - loss: 1.4948 - acc: 0.7966 - val_loss: 1.3752 - val_acc: 0.8347
# Epoch 6/20
# 8640/8640 [==============================] - 95s - loss: 1.4168 - acc: 0.8163 - val_loss: 1.3224 - val_acc: 0.8398
# Epoch 7/20
# ...

# %%
m1.save()
m1 = do_experiment("resnet",[128], lr=1e-4, augment=True, load_model=True, epo1=20, epo2=20, verbose=1)
# Out:
# initializer = he_normal
# added fc-128, dropout keep prob 0.500000, l2 reg 0.005000
# set learning rate and recompile model
# loading /mnt/data/train_aug.npz
# loading val.npz
# loading test.npz
# Train on 51840 samples, validate on 2160 samples
# Epoch 1/20
# 51840/51840 [==============================] - 569s - loss: 0.6611 - acc: 0.9283 - val_loss: 0.8604 - val_acc: 0.8755
# Epoch 2/20
# 51840/51840 [==============================] - 566s - loss: 0.3799 - acc: 0.9807 - val_loss: 0.8154 - val_acc: 0.8750
# Epoch 3/20
# 51840/51840 [==============================] - 567s - loss: 0.2448 - acc: 0.9878 - val_loss: 0.7787 - val_acc: 0.8667
# Epoch 4/20
# 51840/51840 [==============================] - 567s - loss: 0.1592 - acc: 0.9893 - val_loss: 0.7354 - val_acc: 0.8648
# Epoch 5/20
# 51744/51840 [============================>.] - ETA: 1s - loss: 0.1138 - acc: 0.9887
# Epoch 00004: reducing learning rate to 7.999999797903001e-05.
# ...

# %%
m3 = do_experiment("resnet",[256], reg_list=[0.01],lr=1e-4, augment=False, prep=True, load_model=False, epo1=25, epo2=25, verbose=1)
m3.save()
# Out:
# initializer = he_normal
# added fc-256, dropout keep prob 0.500000, l2 reg 0.010000
# loading train.npz
# loading val.npz
# loading test.npz
# 15.0
# 0.0
# -113.594
# -139.148
# Train on 8640 samples, validate on 2160 samples
# Epoch 1/25
# 8640/8640 [==============================] - 103s - loss: 5.4644 - acc: 0.4813 - val_loss: 4.4411 - val_acc: 0.7866
# Epoch 2/25
# 8640/8640 [==============================] - 96s - loss: 4.3434 - acc: 0.7373 - val_loss: 3.9626 - val_acc: 0.8167
# Epoch 3/25
# 8640/8640 [==============================] - 96s - loss: 3.8825 - acc: 0.7903 - val_loss: 3.6129 - val_acc: 0.8324
# Epoch 4/25
# 8640/8640 [==============================] - 96s - loss: 3.5116 - acc: 0.8227 - val_loss: 3.3037 - val_acc: 0.8458
# Epoch 5/25
# 8640/8640 [==============================] - 96s - loss: 3.1875 - acc: 0.8334 - val_loss: 3.0375 - val_acc: 0.8509
# Epoch 6/25
# ...

# %%
m2 = do_experiment("resnet",[512], reg_list=[0.01],lr=1e-4, augment=True, prep=True, load_model=False, epo1=25, epo2=25, verbose=1)
# Out:
# initializer = he_normal
# added fc-512, dropout keep prob 0.500000, l2 reg 0.010000
# loading /mnt/data/train_aug.npz
# loading val.npz
# loading test.npz
# 15.0
# 0.0
# -111.974
# -140.58
# Train on 51840 samples, validate on 2160 samples
# Epoch 1/25
# 51840/51840 [==============================] - 480s - loss: 6.6041 - acc: 0.7330 - val_loss: 4.3882 - val_acc: 0.8505
# Epoch 2/25
# 51840/51840 [==============================] - 472s - loss: 3.2402 - acc: 0.8448 - val_loss: 2.3067 - val_acc: 0.8509
# Epoch 3/25
# 51840/51840 [==============================] - 472s - loss: 1.7402 - acc: 0.8670 - val_loss: 1.3423 - val_acc: 0.8616
# Epoch 4/25
# 51840/51840 [==============================] - 472s - loss: 1.0524 - acc: 0.8804 - val_loss: 0.9143 - val_acc: 0.8634
# Epoch 5/25
# 51840/51840 [==============================] - 472s - loss: 0.7373 - acc: 0.8869 - val_loss: 0.7346 - val_acc: 0.8606
# Epoch 6/25
# ...

# %%
m1 = do_experiment("resnet",[128], reg_list=[0.01],lr=1e-4, augment=True, prep=True, load_model=False, epo1=25, epo2=25, verbose=1)

# %%
m4 = do_experiment("resnet",[1024], reg_list=[0.01],lr=1e-4, augment=True, prep=True, load_model=False, epo1=25, epo2=25, verbose=1)

# %%
m5 = do_experiment("resnet",[1024], reg_list=[0.02], lr=1e-4, augment=True, prep=True, load_model=False, epo1=25, epo2=25, verbose=1)

# %%
m6 = do_experiment("resnet",[1024], reg_list=[0.01], lr=2e-4, augment=True, prep=True, load_model=False, epo1=25, epo2=25, verbose=1)

# %%
m7 = do_experiment("resnet",[1024], reg_list=[0.02], lr=2e-4, augment=True, prep=True, load_model=False, epo1=25, epo2=25, verbose=1)

# %%
m8 = do_experiment("resnet",[1024], reg_list=[0.005], lr=1e-4, augment=True, prep=True, load_model=False, epo1=25, epo2=25, verbose=1)

# %%
m9 = do_experiment("xception",[1024], reg_list=[0.01],lr=1e-4, augment=True, prep=True, load_model=False, epo1=25, epo2=25, verbose=1)
