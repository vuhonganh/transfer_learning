# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import matplotlib.pyplot as plt 
from transfer_models import *

# %%
m1 = exp_2("resnet",[128], reg_list=[0.01], augment=True, use_noise=False, epo1=20, epo2=10)
# Out:
# initializer = he_normal
# added fc-128, dropout keep prob 0.500000, l2 reg 0.010000
# Read data from mydata_1200.npz
#
# Train on 24192 samples, validate on 2016 samples
# Epoch 1/20
# 232s - loss: 3.2057 - acc: 0.5515 - val_loss: 2.2421 - val_acc: 0.8323
# Epoch 2/20
# 231s - loss: 2.2674 - acc: 0.7691 - val_loss: 1.8627 - val_acc: 0.8557
# Epoch 3/20
# 231s - loss: 1.8843 - acc: 0.8168 - val_loss: 1.5877 - val_acc: 0.8730
# Epoch 4/20
# 230s - loss: 1.5951 - acc: 0.8408 - val_loss: 1.3584 - val_acc: 0.8829
# Epoch 5/20
# 230s - loss: 1.3671 - acc: 0.8562 - val_loss: 1.1852 - val_acc: 0.8914
# Epoch 6/20
# 230s - loss: 1.1843 - acc: 0.8683 - val_loss: 1.0428 - val_acc: 0.8889
# Epoch 7/20
# 230s - loss: 1.0393 - acc: 0.8781 - val_loss: 0.9185 - val_acc: 0.8993
# Epoch 8/20
# 230s - loss: 0.9102 - acc: 0.8874 - val_loss: 0.8163 - val_acc: 0.9003
# Epoch 9/20
# 230s - loss: 0.8127 - acc: 0.8934 - val_loss: 0.7405 - val_acc: 0.9008
# Epoch 10/20
# ...

# %%
m2 = exp_2("resnet",[512], reg_list=[0.01], augment=True, use_noise=False, epo1=20, epo2=10)
# Out:
# initializer = he_normal
# added fc-512, dropout keep prob 0.500000, l2 reg 0.010000
# Read data from mydata_1200.npz
#
# Train on 24192 samples, validate on 2016 samples
# Epoch 1/20
# 235s - loss: 7.8289 - acc: 0.6886 - val_loss: 6.2178 - val_acc: 0.8740
# Epoch 2/20
# 237s - loss: 5.3855 - acc: 0.8313 - val_loss: 4.4129 - val_acc: 0.8909
# Epoch 3/20
# 239s - loss: 3.7952 - acc: 0.8684 - val_loss: 3.1398 - val_acc: 0.8924
# Epoch 4/20
# 242s - loss: 2.6978 - acc: 0.8882 - val_loss: 2.2550 - val_acc: 0.9008
# Epoch 5/20
# 242s - loss: 1.9446 - acc: 0.9017 - val_loss: 1.6604 - val_acc: 0.8988
# Epoch 6/20
# 243s - loss: 1.4276 - acc: 0.9110 - val_loss: 1.2475 - val_acc: 0.9053
# Epoch 7/20
# 242s - loss: 1.0805 - acc: 0.9176 - val_loss: 0.9727 - val_acc: 0.9097
# Epoch 8/20
# 242s - loss: 0.8496 - acc: 0.9221 - val_loss: 0.7996 - val_acc: 0.8993
# Epoch 9/20
# 242s - loss: 0.6916 - acc: 0.9252 - val_loss: 0.6784 - val_acc: 0.9033
# Epoch 10/20
# ...

# %%
m3 = exp_2("resnet",[1024], reg_list=[0.01], augment=True, use_noise=False, epo1=20, epo2=10)
# Out:
# initializer = he_normal
# added fc-1024, dropout keep prob 0.500000, l2 reg 0.010000
# Read data from mydata_1200.npz
#
# Train on 24192 samples, validate on 2016 samples
# Epoch 1/20
# 236s - loss: 13.8521 - acc: 0.7195 - val_loss: 10.5928 - val_acc: 0.8626
# Epoch 2/20
# 238s - loss: 8.4921 - acc: 0.8525 - val_loss: 6.5432 - val_acc: 0.8810
# Epoch 3/20
# 239s - loss: 5.2070 - acc: 0.8829 - val_loss: 4.0329 - val_acc: 0.8978
# Epoch 4/20
# 242s - loss: 3.2207 - acc: 0.8992 - val_loss: 2.5421 - val_acc: 0.9028
# Epoch 5/20
# 242s - loss: 2.0473 - acc: 0.9107 - val_loss: 1.6912 - val_acc: 0.8978
# Epoch 6/20
# 240s - loss: 1.3620 - acc: 0.9194 - val_loss: 1.1627 - val_acc: 0.9053
# Epoch 7/20
# 240s - loss: 0.9627 - acc: 0.9230 - val_loss: 0.8686 - val_acc: 0.9023
# Epoch 8/20
# 242s - loss: 0.7293 - acc: 0.9266 - val_loss: 0.6950 - val_acc: 0.9082
# Epoch 9/20
# 242s - loss: 0.5904 - acc: 0.9269 - val_loss: 0.5915 - val_acc: 0.9067
# Epoch 10/20
# ...

# %%
m4 = exp_2("resnet",[128], reg_list=[0.01], augment=False, use_noise=False, epo1=20, epo2=10)
# Out:
# initializer = he_normal
# added fc-128, dropout keep prob 0.500000, l2 reg 0.010000
# Read data from mydata_1200.npz
#
# Train on 8064 samples, validate on 2016 samples
# Epoch 1/20
# 93s - loss: 3.8497 - acc: 0.3751 - val_loss: 2.8403 - val_acc: 0.7584
# Epoch 2/20
# 91s - loss: 2.8787 - acc: 0.6623 - val_loss: 2.3975 - val_acc: 0.8165
# Epoch 3/20
# 92s - loss: 2.5190 - acc: 0.7445 - val_loss: 2.1966 - val_acc: 0.8388
# Epoch 4/20
# 92s - loss: 2.3123 - acc: 0.7743 - val_loss: 2.0530 - val_acc: 0.8447
# Epoch 5/20
# 93s - loss: 2.1325 - acc: 0.8036 - val_loss: 1.9208 - val_acc: 0.8532
# Epoch 6/20
# 92s - loss: 1.9902 - acc: 0.8234 - val_loss: 1.8058 - val_acc: 0.8690
# Epoch 7/20
# 92s - loss: 1.8798 - acc: 0.8289 - val_loss: 1.7104 - val_acc: 0.8700
# Epoch 8/20
# 94s - loss: 1.7533 - acc: 0.8406 - val_loss: 1.6087 - val_acc: 0.8750
# Epoch 9/20
# 93s - loss: 1.6457 - acc: 0.8558 - val_loss: 1.5225 - val_acc: 0.8810
# Epoch 10/20
# ...

# %%
m5 = exp_2("resnet",[512], reg_list=[0.01], augment=False, use_noise=False, epo1=20, epo2=10)
# Out:
# initializer = he_normal
# added fc-512, dropout keep prob 0.500000, l2 reg 0.010000
# Read data from mydata_1200.npz
#
# Train on 8064 samples, validate on 2016 samples
# Epoch 1/20
# 94s - loss: 9.0166 - acc: 0.5453 - val_loss: 7.8144 - val_acc: 0.8070
# Epoch 2/20
# 91s - loss: 7.5199 - acc: 0.7738 - val_loss: 6.8877 - val_acc: 0.8566
# Epoch 3/20
# 91s - loss: 6.6153 - acc: 0.8191 - val_loss: 6.1165 - val_acc: 0.8576
# Epoch 4/20
# 92s - loss: 5.8461 - acc: 0.8403 - val_loss: 5.4242 - val_acc: 0.8700
# Epoch 5/20
# 92s - loss: 5.1672 - acc: 0.8624 - val_loss: 4.8070 - val_acc: 0.8810
# Epoch 6/20
# 94s - loss: 4.5619 - acc: 0.8792 - val_loss: 4.2659 - val_acc: 0.8834
# Epoch 7/20
# 94s - loss: 4.0252 - acc: 0.8914 - val_loss: 3.7918 - val_acc: 0.8849
# Epoch 8/20
# 93s - loss: 3.5512 - acc: 0.9027 - val_loss: 3.3598 - val_acc: 0.8929
# Epoch 9/20
# 94s - loss: 3.1459 - acc: 0.9064 - val_loss: 2.9884 - val_acc: 0.8953
# Epoch 10/20
# ...

# %%
m6 = exp_2("resnet",[1024], reg_list=[0.01], augment=False, use_noise=False, epo1=20, epo2=10)
# Out:
# initializer = he_normal
# added fc-1024, dropout keep prob 0.500000, l2 reg 0.010000
# Read data from mydata_1200.npz
#
# Train on 8064 samples, validate on 2016 samples
# Epoch 1/20
# 94s - loss: 16.1671 - acc: 0.6131 - val_loss: 14.4546 - val_acc: 0.8299
# Epoch 2/20
# 91s - loss: 13.5045 - acc: 0.8067 - val_loss: 12.3122 - val_acc: 0.8661
# Epoch 3/20
# 92s - loss: 11.4405 - acc: 0.8435 - val_loss: 10.4428 - val_acc: 0.8805
# Epoch 4/20
# 93s - loss: 9.6605 - acc: 0.8707 - val_loss: 8.8288 - val_acc: 0.8874
# Epoch 5/20
# 92s - loss: 8.1292 - acc: 0.8894 - val_loss: 7.4308 - val_acc: 0.8963
# Epoch 6/20
# 93s - loss: 6.8220 - acc: 0.9007 - val_loss: 6.2558 - val_acc: 0.8943
# Epoch 7/20
# 94s - loss: 5.7211 - acc: 0.9134 - val_loss: 5.2597 - val_acc: 0.9033
# Epoch 8/20
# 92s - loss: 4.7881 - acc: 0.9234 - val_loss: 4.4290 - val_acc: 0.9013
# Epoch 9/20
# 92s - loss: 4.0243 - acc: 0.9231 - val_loss: 3.7329 - val_acc: 0.9058
# Epoch 10/20
# ...

# %%
matplotlib.rcParams['figure.figsize'] = (10, 6)

# %%
compare_models([m1,m2,m3,m4,m5,m6], ['resnet128_aug', 'resnet512_aug', 'resnet1024_aug', 'resnet128', 'resnet512', 'resnet1024'])
# Out:
# best model resnet512 with test accuracy 0.934722

# %%
m6.save()
